# %%
import pandas as pd
data=pd.read_excel('Refinitiv/test_till_date.xlsx')

# %%
"""#Import all the train excel files in Refinitiv folder and merge them into one dataframe
import os
import glob
os.chdir("Refinitiv")
extension = 'xlsx'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_excel(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8')"""
# Out:
# '#Import all the train excel files in Refinitiv folder and merge them into one dataframe\nimport os\nimport glob\nos.chdir("Refinitiv")\nextension = \'xlsx\'\nall_filenames = [i for i in glob.glob(\'*.{}\'.format(extension))]\n#combine all files in the list\ncombined_csv = pd.concat([pd.read_excel(f) for f in all_filenames ])\n#export to csv\ncombined_csv.to_csv( "combined_csv.csv", index=False, encoding=\'utf-8\')'

# %%
"""combined_csv.head()"""
# Out:
# 'combined_csv.head()'

# %%
data.head()
# Out:
#    SDC Deal No Date Announced  Rank Date  \
# 0   4025744020     2023-01-10 2023-01-10
# 1   3987194020     2022-10-11 2022-10-11
# 2   3989876040     2022-10-06 2022-10-06
# 3   3989437020     2022-10-11 2022-10-11
# 4   3915525020     2022-04-19 2022-04-19
#
#    Rank Value inc. Net Debt of Target\n(USD, Millions)  \
# 0                                           2.250000
# 1                                         108.011000
# 2                                         126.123109
# 3                                           0.000000
# 4                                           0.000000
#
#                        Target Full Name           Target Macro Industry  \
# 0             Severance Trucking Co Inc                     Industrials
# 1      Bassett Furniture Industries Inc  Consumer Products and Services
# 2                         Vale Inco Ltd                       Materials
# 3                      Butler Point Inc                      Financials
# 4  Lyon Fry Cadden Insurance Agency Inc                      Financials
#
#                Target Mid Industry  Target Nation  \
# 0  Transportation & Infrastructure  United States
# 1                 Home Furnishings  United States
# 2                  Metals & Mining         Canada
# 3                            Banks  United States
# 4                        Insurance  United States
#
#               Acquiror Full Name         Acquiror Macro Industry  ...  \
# 0           TLSS Acquisition Inc                      Financials  ...
# 1             CSC Generation Inc                      Financials  ...
# 2              Arco Platform Ltd  Consumer Products and Services  ...
# 3           Fisher National Bank                      Financials  ...
# 4  Higginbotham & Associates LLC                      Financials  ...
#
#   Acquiror PermID Target PermID Target Founded Date Acquiror Founded Date  \
# 0    5.083758e+09  4.297975e+09          1901-01-01                   NaT
# 1             NaN  4.295906e+09          1902-01-01            2016-01-01
# 2    5.065325e+09  4.295861e+09          1902-01-01            2004-01-01
# 3    5.000648e+09  5.024702e+09          1904-01-01            1955-01-01
# 4    4.298070e+09  5.028235e+09          1905-01-01            1948-01-01
#
#   Acquiror Current Assets Last 12 Months\n(USD, Millions)  \
# 0                                                NaN
# 1                                                NaN
# 2                                         331.886103
# 3                                         137.297000
# 4                                                NaN
#
#   Current Assets Last 12 Months \n(USD, Millions)  \
# 0                                             NaN
# 1                                         213.747
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Acquiror Market Value 4 Weeks Prior to Announcement\n(USD, Millions)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Target Market Value 4 Weeks Prior to Announcement\n(USD, Millions)  \
# 0                                                NaN
# 1                                            166.726
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Acquiror EBIT Last 12 Months\n(USD, Millions)  \
# 0                                            NaN
# 1                                            NaN
# 2                                      38.807475
# 3                                       2.635000
# 4                                            NaN
#
#    EBIT Last 12 Months\n(USD, Millions)
# 0                                   NaN
# 1                                31.989
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
# [5 rows x 28 columns]

# %%
AcgAndMerger = data[['Acquiror PermID','Target PermID','Date Announced']]
AcgAndMerger = AcgAndMerger.dropna(subset=['Acquiror PermID','Target PermID'],how='any')
AcgAndMerger['Acquiror PermID']=AcgAndMerger['Acquiror PermID'].astype('str')
AcgAndMerger['Target PermID']=AcgAndMerger['Target PermID'].astype('str')

# %%
AcgAndMerger
# Out:
#       Acquiror PermID Target PermID Date Announced
# 0        5083758169.0  4297975354.0     2023-01-10
# 2        5065324915.0  4295861100.0     2022-10-06
# 3        5000647778.0  5024701873.0     2022-10-11
# 4        4298070370.0  5028235405.0     2022-04-19
# 5        4295884507.0  4295890947.0     2022-07-05
# ...               ...           ...            ...
# 11161    5066619236.0  5084974956.0     2023-04-04
# 11164    5000061106.0  5084981076.0     2023-04-03
# 11165    5085082885.0  5063326320.0     2023-04-03
# 11166    4295890584.0  5060684861.0     2023-04-05
# 11168    5085089089.0  5085088034.0     2023-03-31
#
# [9590 rows x 3 columns]

# %%
AcgAndMerger.to_csv('merged-acq-edges.csv',index=False)
